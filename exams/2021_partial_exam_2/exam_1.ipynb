# %% [markdown]
# # Втор парцијален испит по Роботика 1
#
# Датум: 04.06.2021

# %% [markdown]
# ## Задача 1

# %% [markdown]
# **(35 поени)** Дадена е роботска рака од сликата:

# %%
from IPython import display
display.Image('images/1.png', width=600)

# %% [markdown]
# а) Да се пресмета основниот Јакобијан на раката ${}^0\bf{J}$.

# %% [markdown]
# б) Под претпоставка дека роботската рака се наоѓа во следната конфигурација: $\theta_1 = 90^\circ$, $\theta_2 = 60^\circ$ 0 и $d_3 = 2a$, да се пресметаат силите во зглобовите од раката ако врз извршниот елемент дејствува сила $\bf{F} = \begin{bmatrix} 1 & 0 & 0 \end{bmatrix} ^ \top$.

# %% [markdown]
# в) За дадениот Јакобијан на линеарната брзина на раката да се најдат сингуларитетите на раката. За секој тип сингуларитет да се скицира соодветната конфигурација на раката и да се даде физичка интерпретација.

# %% [markdown]
# ## Решение
